# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

class jobkorea:
    def __init__(self):
        self.result_df = pd.DataFrame()
    def collector(self, keyword):
        url = 'https://www.jobkorea.co.kr/Search/'
        params = {'stext' : keyword}
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
        response = requests.get(url, params = params, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        company = soup.find_all('span', class_ = "Typography_variant_size16__344nw26 Typography_weight_regular__344nw2d Typography_color_gray900__344nw2k styles_mr_space4__dk46ts22")
        recruit = soup.find_all('span', class_ = "Typography_variant_size18__344nw25 Typography_weight_medium__344nw2c Typography_color_gray900__344nw2k Typography_truncate__344nw2t")
        detail = soup.find_all('div', class_ = "Flex_display_flex__i0l0hl2 Flex_gap_space16__i0l0hlj Flex_direction_row__i0l0hl3")
        url_lst = soup.find_all('a', class_ = "Flex_display_flex__i0l0hl2 Flex_gap_space4__i0l0hly Flex_align_center__i0l0hl8 h7nnv12")
        site = ['jobkorea'] * len(url_lst)
        company_lst = [c.text.strip() for c in company]
        recruit_lst = [r.text.replace("\n", " ") for r in recruit]
        detail_lst = [[c.text for c in d.find_all('span')] for d in detail]
        url_lst = [u['href'] for u in url_lst]
        self.result_df = pd.DataFrame({'Site': site,
        'Col_Company': company_lst,
        'Col_Recruit': recruit_lst,
        'Col_Detali' : detail_lst,
        'Col_Url' : url_lst 
        })
        return self.result_df

# %%
collector = jobkorea()
result_df = collector.collector('데이터분석')
display(result_df)
result_df.to_csv('C:/Users/User/Downloads/test/data_tmp/data_jobkorea.csv')
# Out:
#         Site         Col_Company  \
# 0   jobkorea              스피치로그㈜
# 1   jobkorea             네이버파이낸셜
# 2   jobkorea             더치트주식회사
# 3   jobkorea                  연이
# 4   jobkorea               ㈜지바이크
# 5   jobkorea      콘센트릭스서비스코리아(유)
# 6   jobkorea  ㈜트리노드(TreenodInc.)
# 7   jobkorea               ㈜모모랩스
# 8   jobkorea                한패스㈜
# 9   jobkorea              휴먼교육센터
# 10  jobkorea               제이투케이
# 11  jobkorea             롯데손해보험㈜
# 12  jobkorea              ㈜리만코리아
# 13  jobkorea            두산에너빌리티㈜
# 14  jobkorea             ㈜이젠아카데미
# 15  jobkorea      메가스터디컴퓨터아카데미학원
# 16  jobkorea             ㈜커리어게이트
# 17  jobkorea              ㈜엑셀리언트
# 18  jobkorea               ㈜네피리티
# 19  jobkorea              팀스파르타㈜
#
#                                          Col_Recruit  \
# 0                  신입/경력직 데이터분석, 데이터컨설팅,분석보고 작성 및 PT
# 1               [네이버페이] 대쉬보드(데이터분석) 플랫폼 운영 담당자 (계약직)
# 2   데이터 애널리스트 / 데이터분석 전문가 / 통계 전문가 / Data Analyst (통
# 3                        데이터분석 준전문가 자격증 온라인 강의 교사 채용
# 4                        [지쿠] 전략마케팅팀 데이터분석 전문가 경력 채용
# 5                                [Catalyst] 데이터분석 인턴
# 6                    [서울/경력 7년 이상] 데이터분석팀- 데이터 분석 리더
# 7                                  [모모랩스]  데이터분석팀 채용
# 8           [한패스(주)/데이터분석팀] Google Analytics  데이터분석가
# 9             [국비무료/숙식무료]AI/빅데이터분석/풀스택/KDT심화(무료숙식제공)
# 10                   파이썬 인공지능 데이터분석으로 퀀트 개발하실 분 구합니다
# 11            장기상품개발, 재무회계, 데이터분석, 일반보험 상품개발/UW 경력채용
# 12                         [서울] 영업기획 및 데이터분석 (주임-대리)
# 13                2025 채용연계형 인턴십 - 데이터분석 기반 AI 모델 개발
# 14          SQLD/ADSP/FDA자격증 빅데이터분석 평일/주말(토요일) 강사 채용
# 15                 [메가스터디IT] 파이썬, 데이터분석 강사 채용 (방학특강)
# 16                  [메가스터디IT] 파이썬, 데이터분석, ai기초 강사 채용
# 17           (삼성동) 사업 및 영업관리자 모집 (디지털 마케팅, 데이터분석 회사)
# 18                   [(주)네피리티/서울] 데이터분석 및 AI모델 개발 모집
# 19           [기업교육] 실시간 강의 튜터 (Python, 데이터분석, AI 활용)
#
#                                          Col_Detali  \
# 0              [경력무관, 초대졸↑, 정규직, 서울 용산구, ~06/19(목)]
# 1                   [경력1년↑, 초대졸↑, 계약직, 경기 성남시, D-5]
# 2           [경력무관, 대졸↑, 정규직 외 1, 서울 구로구, ~06/18(수)]
# 3            [경력2년↑, 학력무관, 프리랜서, 서울 광진구, ~06/24(화)]
# 4                   [경력3년↑, 대졸↑, 정규직, 서울 강남구, 상시채용]
# 5                     [경력무관, 학력무관, 인턴, 서울 강남구, D-2]
# 6             [경력7년↑, 학력무관, 정규직, 서울 강남구, ~06/21(토)]
# 7          [신입·경력1년↑, 학력무관, 정규직, 서울 강남구, ~06/29(일)]
# 8              [경력3년↑, 대졸↑, 정규직, 서울 성동구, ~06/20(금)]
# 9   [신입·경력, 학력무관, 연수생/교육생, 서울 영등포구 외 14, ~06/13(금)]
# 10              [경력무관, 학력무관, 정규직 외 2, 서울 서초구, 상시채용]
# 11            [경력, 학력무관, 정규직 외 1, 서울 중구, ~06/12(목)]
# 12            [경력3년↑, 학력무관, 정규직, 서울 강남구, ~06/09(월)]
# 13                 [신입, 석사↑, 인턴, 경기 성남시, ~06/09(월)]
# 14        [신입·경력, 초대졸↑, 정규직 외 2, 서울 서초구, ~06/11(수)]
# 15               [경력, 학력무관, 계약직, 서울 강남구, ~06/18(수)]
# 16           [경력, 초대졸↑, 계약직 외 1, 서울 강남구, ~06/18(수)]
# 17             [경력무관, 초대졸↑, 정규직, 서울 강남구, ~06/16(월)]
# 18         [신입·경력, 대졸↑, 정규직 외 1, 서울 서초구, ~06/12(목)]
# 19            [경력3년↑, 학력무관, 정규직, 서울 강남구, ~07/20(일)]
#
#                                               Col_Url
# 0   https://www.jobkorea.co.kr/Recruit/GI_Read/469...
# 1   https://www.jobkorea.co.kr/Recruit/GI_Read/470...
# 2   https://www.jobkorea.co.kr/Recruit/GI_Read/469...
# 3   https://www.jobkorea.co.kr/Recruit/GI_Read/470...
# 4   https://www.jobkorea.co.kr/Recruit/GI_Read/468...
# 5   https://www.jobkorea.co.kr/Recruit/GI_Read/469...
# 6   https://www.jobkorea.co.kr/Recruit/GI_Read/468...
# 7   https://www.jobkorea.co.kr/Recruit/GI_Read/470...
# 8   https://www.jobkorea.co.kr/Recruit/GI_Read/470...
# 9   https://www.jobkorea.co.kr/Recruit/GI_Read/470...
# 10  https://www.jobkorea.co.kr/Recruit/GI_Read/469...
# 11  https://www.jobkorea.co.kr/Recruit/GI_Read/470...
# 12  https://www.jobkorea.co.kr/Recruit/GI_Read/469...
# 13  https://www.jobkorea.co.kr/Recruit/GI_Read/469...
# 14  https://www.jobkorea.co.kr/Recruit/GI_Read/467...
# 15  https://www.jobkorea.co.kr/Recruit/GI_Read/469...
# 16  https://www.jobkorea.co.kr/Recruit/GI_Read/469...
# 17  https://www.jobkorea.co.kr/Recruit/GI_Read/469...
# 18  https://www.jobkorea.co.kr/Recruit/GI_Read/469...
# 19  https://www.jobkorea.co.kr/Recruit/GI_Read/470...
